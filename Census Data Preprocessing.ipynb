# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Loading dataframe
census = pd.read_csv('census_2017.csv',index_col=0)
# Checking
print(census.plot(x='FamilyWork',y='Unemployment',kind='scatter'))
plt.show()
plt.savefig('plot.png',dpi=400)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
census = pd.read_csv('census_2017.csv',index_col=0)
census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74001 entries, 1001020100 to 72153750602
# Data columns (total 36 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             74001 non-null  object
#  1   County            74001 non-null  object
#  2   TotalPop          74001 non-null  int64
#  3   Men               74001 non-null  int64
#  4   Women             74001 non-null  int64
#  5   Hispanic          73305 non-null  float64
#  6   White             73305 non-null  float64
#  7   Black             73305 non-null  float64
#  8   Native            73305 non-null  float64
#  9   Asian             73305 non-null  float64
#  10  Pacific           73305 non-null  float64
#  11  VotingAgeCitizen  74001 non-null  int64
#  12  Income            72885 non-null  float64
#  13  IncomeErr         72885 non-null  float64
#  14  IncomePerCap      73256 non-null  float64
#  15  IncomePerCapErr   73256 non-null  float64
# ...

# %%
census["Men"].describe()
# Out:
# count    74001.000000
# mean      2157.710707
# std       1120.560504
# min          0.000000
# 25%       1416.000000
# 50%       2007.000000
# 75%       2707.000000
# max      32266.000000
# Name: Men, dtype: float64

# %%
#Checking NAs
census.isna()
# Out:
#              State  County  TotalPop    Men  Women  Hispanic  White  Black  \
# TractId
# 1001020100   False   False     False  False  False     False  False  False
# 1001020200   False   False     False  False  False     False  False  False
# 1001020300   False   False     False  False  False     False  False  False
# 1001020400   False   False     False  False  False     False  False  False
# 1001020500   False   False     False  False  False     False  False  False
# ...            ...     ...       ...    ...    ...       ...    ...    ...
# 72153750501  False   False     False  False  False     False  False  False
# 72153750502  False   False     False  False  False     False  False  False
# 72153750503  False   False     False  False  False     False  False  False
# 72153750601  False   False     False  False  False     False  False  False
# 72153750602  False   False     False  False  False     False  False  False
#
# ...

# %%
census.isna().any()
# Out:
# State               False
# County              False
# TotalPop            False
# Men                 False
# Women               False
# Hispanic             True
# White                True
# Black                True
# Native               True
# Asian                True
# Pacific              True
# VotingAgeCitizen    False
# Income               True
# IncomeErr            True
# IncomePerCap         True
# IncomePerCapErr      True
# Poverty              True
# ChildPoverty         True
# Professional         True
# Service              True
# Office               True
# Construction         True
# Production           True
# Drive                True
# Carpool              True
# Transit              True
# Walk                 True
# OtherTransp          True
# WorkAtHome           True
# MeanCommute          True
# Employed            False
# PrivateWork          True
# PublicWork           True
# SelfEmployed         True
# FamilyWork           True
# ...

# %%
# Taking sum of all NAs in a all columns
census.isna().sum()
# Out:
# State                  0
# County                 0
# TotalPop               0
# Men                    0
# Women                  0
# Hispanic             696
# White                696
# Black                696
# Native               696
# Asian                696
# Pacific              696
# VotingAgeCitizen       0
# Income              1116
# IncomeErr           1116
# IncomePerCap         745
# IncomePerCapErr      745
# Poverty              842
# ChildPoverty        1110
# Professional         811
# Service              811
# Office               811
# Construction         811
# Production           811
# Drive                801
# Carpool              801
# Transit              801
# Walk                 801
# OtherTransp          801
# WorkAtHome           801
# MeanCommute          946
# Employed               0
# PrivateWork          811
# PublicWork           811
# SelfEmployed         811
# FamilyWork           811
# Unemployment         810
# dtype: int64

# %%
#Percentage of NAs in whole dataframe
census.isna().sum().sum()/len(census)
# Out:
# 0.32041458899204067

# %%
census.isnull().sum().sum() / (len(census) * len(census.columns))
# Out:
# 0.008900405249778908

# %%
# Checking percentage of NAs in childPovert column
(census['ChildPoverty'].isna().sum().sum()/len(census['ChildPoverty']))* 100
# Out:
# 1.4999797300036486

# %%
#Removing all rows with NAs
a = census.dropna()

# %%
a
# Out:
#                    State           County  TotalPop   Men  Women  Hispanic  \
# TractId
# 1001020100       Alabama   Autauga County      1845   899    946       2.4
# 1001020200       Alabama   Autauga County      2172  1167   1005       1.1
# 1001020300       Alabama   Autauga County      3385  1533   1852       8.0
# 1001020400       Alabama   Autauga County      4267  2001   2266       9.6
# 1001020500       Alabama   Autauga County      9965  5054   4911       0.9
# ...                  ...              ...       ...   ...    ...       ...
# 72153750501  Puerto Rico  Yauco Municipio      6011  3035   2976      99.7
# 72153750502  Puerto Rico  Yauco Municipio      2342   959   1383      99.1
# 72153750503  Puerto Rico  Yauco Municipio      2218  1001   1217      99.5
# 72153750601  Puerto Rico  Yauco Municipio      4380  1964   2416     100.0
# 72153750602  Puerto Rico  Yauco Municipio      3001  1343   1658      99.2
#
# ...

# %%
#Checking shape of the new Dataframe
a.shape
# Out:
# (72718, 36)

# %%
census.shape[0]-a.shape[0]
# Out:
# 1283

# %%
a.isna().any()
# Out:
# State               False
# County              False
# TotalPop            False
# Men                 False
# Women               False
# Hispanic            False
# White               False
# Black               False
# Native              False
# Asian               False
# Pacific             False
# VotingAgeCitizen    False
# Income              False
# IncomeErr           False
# IncomePerCap        False
# IncomePerCapErr     False
# Poverty             False
# ChildPoverty        False
# Professional        False
# Service             False
# Office              False
# Construction        False
# Production          False
# Drive               False
# Carpool             False
# Transit             False
# Walk                False
# OtherTransp         False
# WorkAtHome          False
# MeanCommute         False
# Employed            False
# PrivateWork         False
# PublicWork          False
# SelfEmployed        False
# FamilyWork          False
# ...

# %%
#Checking Duplicates
a.duplicated().any()
# Out:
# False

# %%
#removing duplicates 
census1 = a.drop_duplicates()

# %%
census1
# Out:
#                    State           County  TotalPop   Men  Women  Hispanic  \
# TractId
# 1001020100       Alabama   Autauga County      1845   899    946       2.4
# 1001020200       Alabama   Autauga County      2172  1167   1005       1.1
# 1001020300       Alabama   Autauga County      3385  1533   1852       8.0
# 1001020400       Alabama   Autauga County      4267  2001   2266       9.6
# 1001020500       Alabama   Autauga County      9965  5054   4911       0.9
# ...                  ...              ...       ...   ...    ...       ...
# 72153750501  Puerto Rico  Yauco Municipio      6011  3035   2976      99.7
# 72153750502  Puerto Rico  Yauco Municipio      2342   959   1383      99.1
# 72153750503  Puerto Rico  Yauco Municipio      2218  1001   1217      99.5
# 72153750601  Puerto Rico  Yauco Municipio      4380  1964   2416     100.0
# 72153750602  Puerto Rico  Yauco Municipio      3001  1343   1658      99.2
#
# ...

# %%
census1.shape[0]-a.shape[0]
# Out:
# 0

# %%
#Checking with the method used on Datacamp
a[a.duplicated()]
# Out:
# Empty DataFrame
# Columns: [State, County, TotalPop, Men, Women, Hispanic, White, Black, Native, Asian, Pacific, VotingAgeCitizen, Income, IncomeErr, IncomePerCap, IncomePerCapErr, Poverty, ChildPoverty, Professional, Service, Office, Construction, Production, Drive, Carpool, Transit, Walk, OtherTransp, WorkAtHome, MeanCommute, Employed, PrivateWork, PublicWork, SelfEmployed, FamilyWork, Unemployment]
# Index: []
#
# [0 rows x 36 columns]

# %%
#listing unique names of states to check any mistake in data entery of state names
census["State"].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'Puerto Rico'],
#       dtype=object)

# %%
census["County"].unique()
# Out:
# array(['Autauga County', 'Baldwin County', 'Barbour County', ...,
#        'Villalba Municipio', 'Yabucoa Municipio', 'Yauco Municipio'],
#       dtype=object)

# %%
#checking number of rows of counties in county coulumn
b = census['County'].unique()
b.shape
# Out:
# (1955,)

# %%
census['County']
# Out:
# TractId
# 1001020100      Autauga County
# 1001020200      Autauga County
# 1001020300      Autauga County
# 1001020400      Autauga County
# 1001020500      Autauga County
#                     ...
# 72153750501    Yauco Municipio
# 72153750502    Yauco Municipio
# 72153750503    Yauco Municipio
# 72153750601    Yauco Municipio
# 72153750602    Yauco Municipio
# Name: County, Length: 74001, dtype: object

# %%
census[["County"]]
# Out:
#                       County
# TractId
# 1001020100    Autauga County
# 1001020200    Autauga County
# 1001020300    Autauga County
# 1001020400    Autauga County
# 1001020500    Autauga County
# ...                      ...
# 72153750501  Yauco Municipio
# 72153750502  Yauco Municipio
# 72153750503  Yauco Municipio
# 72153750601  Yauco Municipio
# 72153750602  Yauco Municipio
#
# [74001 rows x 1 columns]

# %%
census[census["Men"]> 12000]
# Out:
#                       State                 County  TotalPop    Men  Women  \
# TractId
# 6071012200       California  San Bernardino County     18959  17128   1831
# 6073013310       California       San Diego County     29528  14300  15228
# 6073018700       California       San Diego County     40402  28658  11744
# 12021011202         Florida         Collier County     25444  13069  12375
# 12095016730         Florida          Orange County     31526  14891  16635
# 12095017104         Florida          Orange County     28818  13803  15015
# 12109020902         Florida       St. Johns County     30506  14910  15596
# 12115002712         Florida        Sarasota County     36147  17071  19076
# 12119911200         Florida          Sumter County     40256  18642  21614
# 13051010700         Georgia         Chatham County     24556  13339  11217
# 13135050606         Georgia        Gwinnett County     24632  12612  12020
# ...

# %%
census.plot(kind='line',x='County',y='TotalPop',rot=90)
# Out:
# <AxesSubplot:xlabel='County'>
